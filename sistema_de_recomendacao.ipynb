# %%
import pandas as pd
import numpy as np

# %%
'''
Este arquivo contém o conjunto de tags disponíveis no conjunto de dados.
'''

# Tags
data_tags = pd.read_csv('tags.dat', sep='\t', error_bad_lines=False, encoding="latin-1")

# Informacoes da base de dados (qtd_instancias, qtd_atributos)
data_tags.shape

# %%
# Imprime as 5 primeiras linhas
data_tags.head()
# Out:
#    tagID           tagValue
# 0      1              metal
# 1      2  alternative metal
# 2      3          goth rock
# 3      4        black metal
# 4      5        death metal

# %%
# Ler arquivo csv
# Artistas
header_artists = ['artist_id', 'Nome', 'url', 'urlpic']
data_artists = pd.read_csv('artists.dat', sep='\t')

# Imprime as 5 primeiras linhas
data_artists.head(5)
# Out:
#    id               name                                         url  \
# 0   1       MALICE MIZER       http://www.last.fm/music/MALICE+MIZER
# 1   2    Diary of Dreams    http://www.last.fm/music/Diary+of+Dreams
# 2   3  Carpathian Forest  http://www.last.fm/music/Carpathian+Forest
# 3   4       Moi dix Mois       http://www.last.fm/music/Moi+dix+Mois
# 4   5        Bella Morte        http://www.last.fm/music/Bella+Morte
#
#                                           pictureURL
# 0    http://userserve-ak.last.fm/serve/252/10808.jpg
# 1  http://userserve-ak.last.fm/serve/252/3052066.jpg
# 2  http://userserve-ak.last.fm/serve/252/40222717...
# 3  http://userserve-ak.last.fm/serve/252/54697835...
# 4  http://userserve-ak.last.fm/serve/252/14789013...

# %%
data_tag_artist = pd.read_csv('user_taggedartists-timestamps.dat', sep='\t', error_bad_lines=False)
data_tag_artist.head()
# Out:
#    userID  artistID  tagID      timestamp
# 0       2        52     13  1238536800000
# 1       2        52     15  1238536800000
# 2       2        52     18  1238536800000
# 3       2        52     21  1238536800000
# 4       2        52     41  1238536800000

# %%
'''
Este arquivo contém os artistas ouvidos por cada usuário.
Ele também fornece uma contagem de audição para cada par [usuário, artista].
'''

data_user_artist = pd.read_csv('user_artists.dat', sep='\t', error_bad_lines=False)
data_user_artist.values
# Out:
# array([[    2,    51, 13883],
#        [    2,    52, 11690],
#        [    2,    53, 11351],
#        ...,
#        [ 2100, 18728,   281],
#        [ 2100, 18729,   280],
#        [ 2100, 18730,   263]])

# %%
a = data_user_artist.groupby('artistID').count()
print(len(a))

# %%
df_user_artist = pd.DataFrame(data_user_artist)
pd.set_option("display.max_rows", 1000)

# %%
df_user_artist.loc
# Out:
#        userID  artistID  weight
# 0           2        51   13883
# 1           2        52   11690
# 2           2        53   11351
# 3           2        54   10300
# 4           2        55    8983
# 5           2        56    6152
# 6           2        57    5955
# 7           2        58    4616
# 8           2        59    4337
# 9           2        60    4147
# 10          2        61    3923
# 11          2        62    3782
# 12          2        63    3735
# 13          2        64    3644
# 14          2        65    3579
# 15          2        66    3312
# 16          2        67    3301
# 17          2        68    2927
# 18          2        69    2720
# 19          2        70    2686
# 20          2        71    2654
# 21          2        72    2619
# 22          2        73    2584
# 23          2        74    2547
# 24          2        75    2397
# 25          2        76    2382
# 26          2        77    2120
# 27          2        78    2119
# ...

# %%
# Quantidade de vezes que cada artista foi ouvido 
total_listen = pd.DataFrame(df_user_artist.groupby('artistID')['weight'].sum())

# %%
total_listen.max()
# Out:
# weight    2393140
# dtype: int64

# %%
# Filtro de artistas
data_artists.loc[data_artists['id'] == 52]
# Out:
#     id       name                                 url  \
# 46  52  Morcheeba  http://www.last.fm/music/Morcheeba
#
#                                            pictureURL
# 46  http://userserve-ak.last.fm/serve/252/46005111...

# %%
user_artist_tags = pd.read_csv('user_taggedartists.dat', sep='\t', error_bad_lines=False)

user_artist_tags
# Out:
#         userID  artistID  tagID  day  month  year
# 0            2        52     13    1      4  2009
# 1            2        52     15    1      4  2009
# 2            2        52     18    1      4  2009
# 3            2        52     21    1      4  2009
# 4            2        52     41    1      4  2009
# 5            2        63     13    1      4  2009
# 6            2        63     14    1      4  2009
# 7            2        63     23    1      4  2009
# 8            2        63     40    1      4  2009
# 9            2        73     13    1      4  2009
# 10           2        73     14    1      4  2009
# 11           2        73     15    1      4  2009
# 12           2        73     18    1      4  2009
# 13           2        73     20    1      4  2009
# 14           2        73     21    1      4  2009
# 15           2        73     22    1      4  2009
# 16           2        73     26    1      4  2009
# 17           2        94     13    1      4  2009
# ...

# %%
from sklearn.datasets import load_digits
 
#Aqui instanciamos a classe load_digits
digits = load_digits()
 
#Aqui armazeno as imagens para darmos uma olhada depois
imagens = digits.images
 
#Aqui estão as arrays 8 x 8 bites
x_data = digits.data
 
#Aqui temos nossos Labels que serão necessário para treinamento
y_data = digits.target

# %%
print(len(x_data))
# Out:
# 1797

# %%
y_data
# Out:
# array([0, 1, 2, ..., 8, 9, 8])

# %%
len(y_data)
# Out:
# 1797
